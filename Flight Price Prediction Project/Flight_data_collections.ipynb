# %% [markdown]
# #### * Importing libraries require for scraping

# %%
import selenium
import pandas as pd
import numpy as np
import time
import requests
import re
from bs4 import BeautifulSoup
from selenium import webdriver 
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import ElementNotVisibleException
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException, ElementClickInterceptedException
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### * Importing webdriver

# %%
driver=webdriver.Chrome('chromedriver.exe')
driver.maximize_window()

# %% [markdown]
# #### * visting the mentioned url

# %%
url = "https://flight.yatra.com/air-search-ui/dom2/trigger?type=O&viewName=normal&flexi=0&noOfSegments=1&origin=DEL&originCountry=IN&destination=BOM&destinationCountry=IN&flight_depart_date=19%2F01%2F2023&ADT=1&CHD=0&INF=0&class=Economy&source=fresco-flights&unqvaldesktop=1318631119934"
driver.get(url)
time.sleep(5)

# %%
Airline_name = []
Depart_time = []
Arival_time = []
Duration = []
Stoppage = []
Price = []
From = []
To = []

#scraping the Airline_name
try:
    air_name = driver.find_elements(By.XPATH,'//span[@class="i-b text ellipsis"]')
    for os in air_name:
        Airline_name.append(os.text)
except NoSuchElementException:
    Airline_name.append('-')

    
#scraping the data of Departure time
try:
    air_dec = driver.find_elements(By.XPATH,'//div[@class="i-b pr"]')
    for os in air_dec:
        Depart_time.append(os.text)
except NoSuchElementException:
    Depart_time.append('-')


#scraping data of the Arival time
try:
    air_ari = driver.find_elements(By.XPATH,'//p[@class="bold fs-15 mb-2 pr time"]')
    for disp in air_ari:
        Arival_time.append(disp.text)
except NoSuchElementException:
    Arival_time.append("-")


# scraping data of Duration of the flight
try:
    dur = driver.find_elements(By.XPATH,'//p[@class="fs-12 bold du mb-2"]')
    for pro in dur:
        Duration.append(pro.text)
except NoSuchElementException:
    Duration.append('-')
    
    
# scraping the number of stoppage
try:
    stop = driver.find_elements(By.XPATH,'//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]')
    for pro in stop:
        Stoppage.append(pro.text)
except NoSuchElementException:
    Stoppage.append('-')
    
    
#scraping the data of fare of
try:
    op_ser = driver.find_elements(By.XPATH,'//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
    for os in op_ser:
        Price.append(os.text)
except NoSuchElementException:
    Price.append('-')
    
    
# scraping  boarding location 
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        From.append(i.text)
except NoSuchElementException:
    From.append('-')
    
    
# scraping  landing location
try:
    name = driver.find_elements(By.XPATH,"//p[2][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        To.append(i.text)
except NoSuchElementException:
    To.append('-')

# %%
import pandas as pd
df1 = pd.DataFrame()
df1['Airline name']=Airline_name
df1['From']=From
df1['To']=To
df1['Arival time']=Arival_time
df1['Depart time']=Depart_time
df1['Stoppage']=Stoppage
df1['Duration']=Duration
df1['Price']=Price
df1
# Out:
#    Airline name       From      To     Arival time Depart time  Stoppage  \
# 0     Air India  New Delhi  Mumbai           23:35       21:20  Non Stop
# 1     Air India  New Delhi  Mumbai  00:45\n+ 1 day       22:30  Non Stop
# 2      Go First  New Delhi  Mumbai           22:05       20:00  Non Stop
# 3      Go First  New Delhi  Mumbai           23:15       21:00  Non Stop
# 4        IndiGo  New Delhi  Mumbai  01:20\n+ 1 day       23:00  Non Stop
# ..          ...        ...     ...             ...         ...       ...
# 87       IndiGo  New Delhi  Mumbai           20:10       15:25    1 Stop
# 88      Vistara  New Delhi  Mumbai  16:55\n+ 1 day       20:40    1 Stop
# 89      Vistara  New Delhi  Mumbai  23:10\n+ 1 day       20:40    1 Stop
# 90      Vistara  New Delhi  Mumbai           23:10       17:35    1 Stop
# 91      Vistara  New Delhi  Mumbai           23:10       14:45    1 Stop
#
#    Duration   Price
# 0    2h 15m   5,317
# 1    2h 15m   5,317
# 2    2h 05m   5,899
# ...

# %%
df1.to_csv('df1')

# %%
next_search1=driver.find_element(By.XPATH,"/html/body/section[2]/section/section[2]/section[1]/div[1]/div/div[1]/div/ul/li[2]/div/p[1]").click()

# %%
Airline_name = []
Depart_time = []
Arival_time = []
Duration = []
Stoppage = []
Price = []
From = []
To = []

#scraping the Airline_name
try:
    air_name = driver.find_elements(By.XPATH,'//span[@class="i-b text ellipsis"]')
    for os in air_name:
        Airline_name.append(os.text)
except NoSuchElementException:
    Airline_name.append('-')

    
#scraping the data of Departure time
try:
    air_dec = driver.find_elements(By.XPATH,'//div[@class="i-b pr"]')
    for os in air_dec:
        Depart_time.append(os.text)
except NoSuchElementException:
    Depart_time.append('-')


#scraping data of the Arival time
try:
    air_ari = driver.find_elements(By.XPATH,'//p[@class="bold fs-15 mb-2 pr time"]')
    for disp in air_ari:
        Arival_time.append(disp.text)
except NoSuchElementException:
    Arival_time.append("-")


# scraping data of Duration of the flight
try:
    dur = driver.find_elements(By.XPATH,'//p[@class="fs-12 bold du mb-2"]')
    for pro in dur:
        Duration.append(pro.text)
except NoSuchElementException:
    Duration.append('-')
    
    
# scraping the number of stoppage
try:
    stop = driver.find_elements(By.XPATH,'//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]')
    for pro in stop:
        Stoppage.append(pro.text)
except NoSuchElementException:
    Stoppage.append('-')
    
    
#scraping the data of fare of
try:
    op_ser = driver.find_elements(By.XPATH,'//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
    for os in op_ser:
        Price.append(os.text)
except NoSuchElementException:
    Price.append('-')
    
    
# scraping  boarding location 
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        From.append(i.text)
except NoSuchElementException:
    From.append('-')
    
    
# scraping  landing location
try:
    name = driver.find_elements(By.XPATH,"//p[2][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        To.append(i.text)
except NoSuchElementException:
    To.append('-')

# %%
df2 = pd.DataFrame()
df2['Airline name']=Airline_name
df2['From']=From
df2['To']=To
df2['Arival time']=Arival_time
df2['Depart time']=Depart_time
df2['Stoppage']=Stoppage
df2['Duration']=Duration
df2['Price']=Price
df2
# Out:
#     Airline name       From      To     Arival time Depart time  Stoppage  \
# 0         IndiGo  New Delhi  Mumbai           07:15       04:45  Non Stop
# 1       Air Asia  New Delhi  Mumbai           13:05       04:55    1 Stop
# 2       Go First  New Delhi  Mumbai           04:50       02:40  Non Stop
# 3       Go First  New Delhi  Mumbai           08:10       06:00  Non Stop
# 4       Go First  New Delhi  Mumbai  00:40\n+ 1 day       22:30  Non Stop
# ..           ...        ...     ...             ...         ...       ...
# 150      Vistara  New Delhi  Mumbai           23:10       17:35    1 Stop
# 151      Vistara  New Delhi  Mumbai           23:10       14:45    1 Stop
# 152      Vistara  New Delhi  Mumbai           20:15       14:10    1 Stop
# 153       IndiGo  New Delhi  Mumbai           23:35       18:40    1 Stop
# 154       IndiGo  New Delhi  Mumbai           18:40       09:40    1 Stop
#
#     Duration   Price
# 0     2h 30m   5,639
# 1     8h 10m   5,758
# ...

# %%
df2.to_csv('df2')

# %%
next_search1=driver.find_element(By.XPATH,"/html/body/section[2]/section/section[2]/section[1]/div[1]/div/div[1]/div/ul/li[3]/div/p[1]").click()

# %%
Airline_name = []
Depart_time = []
Arival_time = []
Duration = []
Stoppage = []
Price = []
From = []
To = []

#scraping the Airline_name
try:
    air_name = driver.find_elements(By.XPATH,'//span[@class="i-b text ellipsis"]')
    for os in air_name:
        Airline_name.append(os.text)
except NoSuchElementException:
    Airline_name.append('-')

    
#scraping the data of Departure time
try:
    air_dec = driver.find_elements(By.XPATH,'//div[@class="i-b pr"]')
    for os in air_dec:
        Depart_time.append(os.text)
except NoSuchElementException:
    Depart_time.append('-')


#scraping data of the Arival time
try:
    air_ari = driver.find_elements(By.XPATH,'//p[@class="bold fs-15 mb-2 pr time"]')
    for disp in air_ari:
        Arival_time.append(disp.text)
except NoSuchElementException:
    Arival_time.append("-")


# scraping data of Duration of the flight
try:
    dur = driver.find_elements(By.XPATH,'//p[@class="fs-12 bold du mb-2"]')
    for pro in dur:
        Duration.append(pro.text)
except NoSuchElementException:
    Duration.append('-')
    
    
# scraping the number of stoppage
try:
    stop = driver.find_elements(By.XPATH,'//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]')
    for pro in stop:
        Stoppage.append(pro.text)
except NoSuchElementException:
    Stoppage.append('-')
    
    
#scraping the data of fare of
try:
    op_ser = driver.find_elements(By.XPATH,'//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
    for os in op_ser:
        Price.append(os.text)
except NoSuchElementException:
    Price.append('-')
    
    
# scraping  boarding location 
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        From.append(i.text)
except NoSuchElementException:
    From.append('-')
    
    
# scraping  landing location
try:
    name = driver.find_elements(By.XPATH,"//p[2][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        To.append(i.text)
except NoSuchElementException:
    To.append('-')

# %%
df3 = pd.DataFrame()
df3['Airline name']=Airline_name
df3['From']=From
df3['To']=To
df3['Arival time']=Arival_time
df3['Depart time']=Depart_time
df3['Stoppage']=Stoppage
df3['Duration']=Duration
df3['Price']=Price
df3
# Out:
#     Airline name       From      To     Arival time Depart time  Stoppage  \
# 0       SpiceJet  New Delhi  Mumbai           20:05       18:10  Non Stop
# 1       SpiceJet  New Delhi  Mumbai           22:05       20:00  Non Stop
# 2      Air India  New Delhi  Mumbai           22:10       20:00  Non Stop
# 3      Air India  New Delhi  Mumbai           23:35       21:20  Non Stop
# 4      Air India  New Delhi  Mumbai  00:45\n+ 1 day       22:30  Non Stop
# ..           ...        ...     ...             ...         ...       ...
# 152     Go First  New Delhi  Mumbai           18:35       10:20    1 Stop
# 153    Air India  New Delhi  Mumbai  09:55\n+ 1 day       21:30    1 Stop
# 154    Air India  New Delhi  Mumbai  14:55\n+ 1 day       21:30    1 Stop
# 155    Air India  New Delhi  Mumbai           11:20       09:00  Non Stop
# 156      Vistara  New Delhi  Mumbai           23:30       15:45    1 Stop
#
#     Duration   Price
# 0     1h 55m   5,034
# 1     2h 05m   5,034
# ...

# %%
df3.to_csv('df3')

# %%
driver.close()

# %%
driver=webdriver.Chrome('chromedriver.exe')
driver.maximize_window()

# %%
url = "https://flight.yatra.com/air-search-ui/dom2/trigger?type=O&viewName=normal&flexi=0&noOfSegments=1&origin=BOM&originCountry=IN&destination=DEL&destinationCountry=IN&flight_depart_date=19%2F01%2F2023&ADT=1&CHD=0&INF=0&class=Economy&source=fresco-home&unqvaldesktop=333579764068"
driver.get(url)
time.sleep(5)

# %%
Airline_name = []
Depart_time = []
Arival_time = []
Duration = []
Stoppage = []
Price = []
From = []
To = []

#scraping the Airline_name
try:
    air_name = driver.find_elements(By.XPATH,'//span[@class="i-b text ellipsis"]')
    for os in air_name:
        Airline_name.append(os.text)
except NoSuchElementException:
    Airline_name.append('-')

    
#scraping the data of Departure time
try:
    air_dec = driver.find_elements(By.XPATH,'//div[@class="i-b pr"]')
    for os in air_dec:
        Depart_time.append(os.text)
except NoSuchElementException:
    Depart_time.append('-')


#scraping data of the Arival time
try:
    air_ari = driver.find_elements(By.XPATH,'//p[@class="bold fs-15 mb-2 pr time"]')
    for disp in air_ari:
        Arival_time.append(disp.text)
except NoSuchElementException:
    Arival_time.append("-")


# scraping data of Duration of the flight
try:
    dur = driver.find_elements(By.XPATH,'//p[@class="fs-12 bold du mb-2"]')
    for pro in dur:
        Duration.append(pro.text)
except NoSuchElementException:
    Duration.append('-')
    
    
# scraping the number of stoppage
try:
    stop = driver.find_elements(By.XPATH,'//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]')
    for pro in stop:
        Stoppage.append(pro.text)
except NoSuchElementException:
    Stoppage.append('-')
    
    
#scraping the data of fare of
try:
    op_ser = driver.find_elements(By.XPATH,'//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
    for os in op_ser:
        Price.append(os.text)
except NoSuchElementException:
    Price.append('-')
    
    
# scraping  boarding location 
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        From.append(i.text)
except NoSuchElementException:
    From.append('-')
    
    
# scraping  landing location
try:
    name = driver.find_elements(By.XPATH,"//p[2][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        To.append(i.text)
except NoSuchElementException:
    To.append('-')

# %%
df4 = pd.DataFrame()
df4['Airline name']=Airline_name
df4['From']=From
df4['To']=To
df4['Arival time']=Arival_time
df4['Depart time']=Depart_time
df4['Stoppage']=Stoppage
df4['Duration']=Duration
df4['Price']=Price
df4
# Out:
#    Airline name    From         To     Arival time Depart time  Stoppage  \
# 0        IndiGo  Mumbai  New Delhi  01:40\n+ 1 day       23:15  Non Stop
# 1      Go First  Mumbai  New Delhi  01:05\n+ 1 day       22:55  Non Stop
# 2      Go First  Mumbai  New Delhi           23:30       21:15  Non Stop
# 3      Go First  Mumbai  New Delhi  02:00\n+ 1 day       23:45  Non Stop
# 4        IndiGo  Mumbai  New Delhi  00:40\n+ 1 day       22:15  Non Stop
# ..          ...     ...        ...             ...         ...       ...
# 82      Vistara  Mumbai  New Delhi  12:35\n+ 1 day       17:20    1 Stop
# 83      Vistara  Mumbai  New Delhi  09:20\n+ 1 day       22:30    1 Stop
# 84      Vistara  Mumbai  New Delhi  15:20\n+ 1 day       19:10    1 Stop
# 85    Air India  Mumbai  New Delhi  19:50\n+ 1 day       17:50    1 Stop
# 86      Vistara  Mumbai  New Delhi  15:35\n+ 1 day       22:30    1 Stop
#
#    Duration   Price
# 0    2h 25m   5,628
# 1    2h 10m   5,629
# 2    2h 15m   5,629
# ...

# %%
df4.to_csv('df4')

# %%
next_search=driver.find_element(By.XPATH,"/html/body/section[2]/section/section[2]/section[1]/div[1]/div/div[1]/div/ul/li[2]/div/p[1]").click()

# %%
Airline_name = []
Depart_time = []
Arival_time = []
Duration = []
Stoppage = []
Price = []
From = []
To = []

#scraping the Airline_name
try:
    air_name = driver.find_elements(By.XPATH,'//span[@class="i-b text ellipsis"]')
    for os in air_name:
        Airline_name.append(os.text)
except NoSuchElementException:
    Airline_name.append('-')

    
#scraping the data of Departure time
try:
    air_dec = driver.find_elements(By.XPATH,'//div[@class="i-b pr"]')
    for os in air_dec:
        Depart_time.append(os.text)
except NoSuchElementException:
    Depart_time.append('-')


#scraping data of the Arival time
try:
    air_ari = driver.find_elements(By.XPATH,'//p[@class="bold fs-15 mb-2 pr time"]')
    for disp in air_ari:
        Arival_time.append(disp.text)
except NoSuchElementException:
    Arival_time.append("-")


# scraping data of Duration of the flight
try:
    dur = driver.find_elements(By.XPATH,'//p[@class="fs-12 bold du mb-2"]')
    for pro in dur:
        Duration.append(pro.text)
except NoSuchElementException:
    Duration.append('-')
    
    
# scraping the number of stoppage
try:
    stop = driver.find_elements(By.XPATH,'//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]')
    for pro in stop:
        Stoppage.append(pro.text)
except NoSuchElementException:
    Stoppage.append('-')
    
    
#scraping the data of fare of
try:
    op_ser = driver.find_elements(By.XPATH,'//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
    for os in op_ser:
        Price.append(os.text)
except NoSuchElementException:
    Price.append('-')
    
    
# scraping  boarding location 
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        From.append(i.text)
except NoSuchElementException:
    From.append('-')
    
    
# scraping  landing location
try:
    name = driver.find_elements(By.XPATH,"//p[2][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        To.append(i.text)
except NoSuchElementException:
    To.append('-')

# %%
df5 = pd.DataFrame()
df5['Airline name']=Airline_name
df5['From']=From
df5['To']=To
df5['Arival time']=Arival_time
df5['Depart time']=Depart_time
df5['Stoppage']=Stoppage
df5['Duration']=Duration
df5['Price']=Price
df5
# Out:
#     Airline name    From         To     Arival time Depart time  Stoppage  \
# 0         IndiGo  Mumbai  New Delhi           04:45       02:30  Non Stop
# 1         IndiGo  Mumbai  New Delhi  01:40\n+ 1 day       23:15  Non Stop
# 2       Go First  Mumbai  New Delhi           08:00       05:50  Non Stop
# 3       Go First  Mumbai  New Delhi  01:05\n+ 1 day       22:55  Non Stop
# 4       Go First  Mumbai  New Delhi  02:00\n+ 1 day       23:45  Non Stop
# ..           ...     ...        ...             ...         ...       ...
# 143      Vistara  Mumbai  New Delhi           23:55       16:00    1 Stop
# 144      Vistara  Mumbai  New Delhi           23:55       17:55    1 Stop
# 145      Vistara  Mumbai  New Delhi           15:35       10:45    1 Stop
# 146      Vistara  Mumbai  New Delhi           23:55       17:30    1 Stop
# 147      Vistara  Mumbai  New Delhi  09:20\n+ 1 day       19:20    1 Stop
#
#     Duration   Price
# 0     2h 15m   5,628
# 1     2h 25m   5,628
# ...

# %%
df5.to_csv('df5')

# %%
next_search=driver.find_element(By.XPATH,"/html/body/section[2]/section/section[2]/section[1]/div[1]/div/div[1]/div/ul/li[3]/div/p[1]").click()

# %%
Airline_name = []
Depart_time = []
Arival_time = []
Duration = []
Stoppage = []
Price = []
From = []
To = []

#scraping the Airline_name
try:
    air_name = driver.find_elements(By.XPATH,'//span[@class="i-b text ellipsis"]')
    for os in air_name:
        Airline_name.append(os.text)
except NoSuchElementException:
    Airline_name.append('-')

    
#scraping the data of Departure time
try:
    air_dec = driver.find_elements(By.XPATH,'//div[@class="i-b pr"]')
    for os in air_dec:
        Depart_time.append(os.text)
except NoSuchElementException:
    Depart_time.append('-')


#scraping data of the Arival time
try:
    air_ari = driver.find_elements(By.XPATH,'//p[@class="bold fs-15 mb-2 pr time"]')
    for disp in air_ari:
        Arival_time.append(disp.text)
except NoSuchElementException:
    Arival_time.append("-")


# scraping data of Duration of the flight
try:
    dur = driver.find_elements(By.XPATH,'//p[@class="fs-12 bold du mb-2"]')
    for pro in dur:
        Duration.append(pro.text)
except NoSuchElementException:
    Duration.append('-')
    
    
# scraping the number of stoppage
try:
    stop = driver.find_elements(By.XPATH,'//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]')
    for pro in stop:
        Stoppage.append(pro.text)
except NoSuchElementException:
    Stoppage.append('-')
    
    
#scraping the data of fare of
try:
    op_ser = driver.find_elements(By.XPATH,'//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
    for os in op_ser:
        Price.append(os.text)
except NoSuchElementException:
    Price.append('-')
    
    
# scraping  boarding location 
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        From.append(i.text)
except NoSuchElementException:
    From.append('-')
    
    
# scraping  landing location
try:
    name = driver.find_elements(By.XPATH,"//p[2][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        To.append(i.text)
except NoSuchElementException:
    To.append('-')

# %%
df6 = pd.DataFrame()
df6['Airline name']=Airline_name
df6['From']=From
df6['To']=To
df6['Arival time']=Arival_time
df6['Depart time']=Depart_time
df6['Stoppage']=Stoppage
df6['Duration']=Duration
df6['Price']=Price
df6
# Out:
#     Airline name    From         To     Arival time Depart time  Stoppage  \
# 0      Air India  Mumbai  New Delhi           18:40       16:35  Non Stop
# 1       Air Asia  Mumbai  New Delhi           23:05       15:15    1 Stop
# 2         IndiGo  Mumbai  New Delhi           04:45       02:30  Non Stop
# 3         IndiGo  Mumbai  New Delhi           08:20       06:05  Non Stop
# 4         IndiGo  Mumbai  New Delhi  01:40\n+ 1 day       23:15  Non Stop
# ..           ...     ...        ...             ...         ...       ...
# 146     Air Asia  Mumbai  New Delhi           14:30       07:35    1 Stop
# 147    Air India  Mumbai  New Delhi           17:25       12:15    1 Stop
# 148       IndiGo  Mumbai  New Delhi           13:00       06:20    1 Stop
# 149       IndiGo  Mumbai  New Delhi           13:35       08:05    1 Stop
# 150      Vistara  Mumbai  New Delhi           22:45       10:45    1 Stop
#
#     Duration   Price
# 0     2h 05m   5,305
# 1     7h 50m   5,542
# ...

# %%
df6.to_csv('df6')

# %%
next_search=driver.find_element(By.XPATH,"/html/body/section[2]/section/section[2]/section[1]/div[1]/div/div[1]/div/ul/li[3]/div/p[1]").click()

# %%
driver.close()

# %%
driver=webdriver.Chrome('chromedriver.exe')
driver.maximize_window()

# %%
url = "https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=GOI&destinationCountry=IN&flexi=0&flight_depart_date=19%2F01%2F2023&hb=0&noOfSegments=1&origin=BOM&originCountry=IN&type=O&unique=1415082665504&version=1.1&viewName=normal"
driver.get(url)
time.sleep(5)

# %%
Airline_name = []
Depart_time = []
Arival_time = []
Duration = []
Stoppage = []
Price = []
From = []
To = []

#scraping the Airline_name
try:
    air_name = driver.find_elements(By.XPATH,'//span[@class="i-b text ellipsis"]')
    for os in air_name:
        Airline_name.append(os.text)
except NoSuchElementException:
    Airline_name.append('-')

    
#scraping the data of Departure time
try:
    air_dec = driver.find_elements(By.XPATH,'//div[@class="i-b pr"]')
    for os in air_dec:
        Depart_time.append(os.text)
except NoSuchElementException:
    Depart_time.append('-')


#scraping data of the Arival time
try:
    air_ari = driver.find_elements(By.XPATH,'//p[@class="bold fs-15 mb-2 pr time"]')
    for disp in air_ari:
        Arival_time.append(disp.text)
except NoSuchElementException:
    Arival_time.append("-")


# scraping data of Duration of the flight
try:
    dur = driver.find_elements(By.XPATH,'//p[@class="fs-12 bold du mb-2"]')
    for pro in dur:
        Duration.append(pro.text)
except NoSuchElementException:
    Duration.append('-')
    
    
# scraping the number of stoppage
try:
    stop = driver.find_elements(By.XPATH,'//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]')
    for pro in stop:
        Stoppage.append(pro.text)
except NoSuchElementException:
    Stoppage.append('-')
    
    
#scraping the data of fare of
try:
    op_ser = driver.find_elements(By.XPATH,'//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
    for os in op_ser:
        Price.append(os.text)
except NoSuchElementException:
    Price.append('-')
    
    
# scraping  boarding location 
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        From.append(i.text)
except NoSuchElementException:
    From.append('-')
    
    
# scraping  landing location
try:
    name = driver.find_elements(By.XPATH,"//p[2][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        To.append(i.text)
except NoSuchElementException:
    To.append('-')

# %%
df7 = pd.DataFrame()
df7['Airline name']=Airline_name
df7['From']=From
df7['To']=To
df7['Arival time']=Arival_time
df7['Depart time']=Depart_time
df7['Stoppage']=Stoppage
df7['Duration']=Duration
df7['Price']=Price
df7
# Out:
#     Airline name    From   To      Arival time Depart time   Stoppage  \
# 0       Air Asia  Mumbai  Goa   00:30\n+ 1 day       23:20   Non Stop
# 1       SpiceJet  Mumbai  Goa            22:20       21:05   Non Stop
# 2   Alliance Air  Mumbai  Goa            20:30       19:00   Non Stop
# 3       Go First  Mumbai  Goa            23:25       22:05   Non Stop
# 4      Air India  Mumbai  Goa            23:35       22:15   Non Stop
# 5         IndiGo  Mumbai  Goa            23:10       21:55   Non Stop
# 6        Vistara  Mumbai  Goa            22:10       20:55   Non Stop
# 7       Air Asia  Mumbai  Goa   05:25\n+ 1 day       20:35     1 Stop
# 8       Air Asia  Mumbai  Goa   05:25\n+ 1 day       19:40     1 Stop
# 9       Air Asia  Mumbai  Goa   06:45\n+ 1 day       20:35     1 Stop
# 10      Air Asia  Mumbai  Goa   06:45\n+ 1 day       19:40     1 Stop
# 11      Air Asia  Mumbai  Goa   05:25\n+ 1 day       21:50     1 Stop
# ...

# %%
df7.to_csv('df7')

# %%
next_search=driver.find_element(By.XPATH,"/html/body/section[2]/section/section[2]/section[1]/div[1]/div/div[1]/div/ul/li[2]/div/p[1]").click()

# %%
Airline_name = []
Depart_time = []
Arival_time = []
Duration = []
Stoppage = []
Price = []
From = []
To = []

#scraping the Airline_name
try:
    air_name = driver.find_elements(By.XPATH,'//span[@class="i-b text ellipsis"]')
    for os in air_name:
        Airline_name.append(os.text)
except NoSuchElementException:
    Airline_name.append('-')

    
#scraping the data of Departure time
try:
    air_dec = driver.find_elements(By.XPATH,'//div[@class="i-b pr"]')
    for os in air_dec:
        Depart_time.append(os.text)
except NoSuchElementException:
    Depart_time.append('-')


#scraping data of the Arival time
try:
    air_ari = driver.find_elements(By.XPATH,'//p[@class="bold fs-15 mb-2 pr time"]')
    for disp in air_ari:
        Arival_time.append(disp.text)
except NoSuchElementException:
    Arival_time.append("-")


# scraping data of Duration of the flight
try:
    dur = driver.find_elements(By.XPATH,'//p[@class="fs-12 bold du mb-2"]')
    for pro in dur:
        Duration.append(pro.text)
except NoSuchElementException:
    Duration.append('-')
    
    
# scraping the number of stoppage
try:
    stop = driver.find_elements(By.XPATH,'//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]')
    for pro in stop:
        Stoppage.append(pro.text)
except NoSuchElementException:
    Stoppage.append('-')
    
    
#scraping the data of fare of
try:
    op_ser = driver.find_elements(By.XPATH,'//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
    for os in op_ser:
        Price.append(os.text)
except NoSuchElementException:
    Price.append('-')
    
    
# scraping  boarding location 
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        From.append(i.text)
except NoSuchElementException:
    From.append('-')
    
    
# scraping  landing location
try:
    name = driver.find_elements(By.XPATH,"//p[2][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        To.append(i.text)
except NoSuchElementException:
    To.append('-')

# %%
df8 = pd.DataFrame()
df8['Airline name']=Airline_name
df8['From']=From
df8['To']=To
df8['Arival time']=Arival_time
df8['Depart time']=Depart_time
df8['Stoppage']=Stoppage
df8['Duration']=Duration
df8['Price']=Price
df8
# Out:
#    Airline name    From   To     Arival time Depart time   Stoppage Duration  \
# 0      Go First  Mumbai  Goa           23:25       22:05   Non Stop   1h 20m
# 1      SpiceJet  Mumbai  Goa           23:55       22:45   Non Stop   1h 10m
# 2      SpiceJet  Mumbai  Goa           22:20       21:05   Non Stop   1h 15m
# 3      Air Asia  Mumbai  Goa           02:25       01:15   Non Stop   1h 10m
# 4      Air Asia  Mumbai  Goa  00:30\n+ 1 day       23:20   Non Stop   1h 10m
# ..          ...     ...  ...             ...         ...        ...      ...
# 78      Vistara  Mumbai  Goa           21:20       06:30     1 Stop  14h 50m
# 79    Air India  Mumbai  Goa  00:40\n+ 1 day       18:00     1 Stop   6h 40m
# 80      Vistara  Mumbai  Goa           21:20       14:40     1 Stop   6h 40m
# 81      Vistara  Mumbai  Goa           21:20       12:25     1 Stop   8h 55m
# 82    Air India  Mumbai  Goa  00:40\n+ 1 day       12:15  2 Stop(s)  12h 25m
#
#      Price
# 0    4,246
# 1    4,497
# ...

# %%
df8.to_csv('df8')

# %%
next_search=driver.find_element(By.XPATH,"/html/body/section[1]/section/div/div/form/ul[2]/li[2]/i").click()

# %%
next_search=driver.find_element(By.XPATH,"/html/body/section[1]/section/div/div/form/div[1]/div/button").click()

# %%
Airline_name = []
Depart_time = []
Arival_time = []
Duration = []
Stoppage = []
Price = []
From = []
To = []

#scraping the Airline_name
try:
    air_name = driver.find_elements(By.XPATH,'//span[@class="i-b text ellipsis"]')
    for os in air_name:
        Airline_name.append(os.text)
except NoSuchElementException:
    Airline_name.append('-')

    
#scraping the data of Departure time
try:
    air_dec = driver.find_elements(By.XPATH,'//div[@class="i-b pr"]')
    for os in air_dec:
        Depart_time.append(os.text)
except NoSuchElementException:
    Depart_time.append('-')


#scraping data of the Arival time
try:
    air_ari = driver.find_elements(By.XPATH,'//p[@class="bold fs-15 mb-2 pr time"]')
    for disp in air_ari:
        Arival_time.append(disp.text)
except NoSuchElementException:
    Arival_time.append("-")


# scraping data of Duration of the flight
try:
    dur = driver.find_elements(By.XPATH,'//p[@class="fs-12 bold du mb-2"]')
    for pro in dur:
        Duration.append(pro.text)
except NoSuchElementException:
    Duration.append('-')
    
    
# scraping the number of stoppage
try:
    stop = driver.find_elements(By.XPATH,'//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]')
    for pro in stop:
        Stoppage.append(pro.text)
except NoSuchElementException:
    Stoppage.append('-')
    
    
#scraping the data of fare of
try:
    op_ser = driver.find_elements(By.XPATH,'//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
    for os in op_ser:
        Price.append(os.text)
except NoSuchElementException:
    Price.append('-')
    
    
# scraping  boarding location 
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        From.append(i.text)
except NoSuchElementException:
    From.append('-')
    
    
# scraping  landing location
try:
    name = driver.find_elements(By.XPATH,"//p[2][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        To.append(i.text)
except NoSuchElementException:
    To.append('-')

# %%
df9 = pd.DataFrame()
df9['Airline name']=Airline_name
df9['From']=From
df9['To']=To
df9['Arival time']=Arival_time
df9['Depart time']=Depart_time
df9['Stoppage']=Stoppage
df9['Duration']=Duration
df9['Price']=Price
df9
# Out:
#    Airline name From      To     Arival time Depart time  Stoppage Duration  \
# 0      SpiceJet  Goa  Mumbai           06:25       05:10  Non Stop   1h 15m
# 1        IndiGo  Goa  Mumbai           07:55       06:45  Non Stop   1h 10m
# 2        IndiGo  Goa  Mumbai           17:45       16:30  Non Stop   1h 15m
# 3        IndiGo  Goa  Mumbai  01:00\n+ 1 day       23:45  Non Stop   1h 15m
# 4      Air Asia  Goa  Mumbai           04:00       02:55  Non Stop   1h 05m
# ..          ...  ...     ...             ...         ...       ...      ...
# 72    Air India  Goa  Mumbai           20:15       07:35    1 Stop  12h 40m
# 73    Air India  Goa  Mumbai           21:25       07:35    1 Stop  13h 50m
# 74    Air India  Goa  Mumbai           16:20       01:45    1 Stop  14h 35m
# 75    Air India  Goa  Mumbai           20:15       01:45    1 Stop  18h 30m
# 76    Air India  Goa  Mumbai           21:25       01:45    1 Stop  19h 40m
#
#      Price
# 0    2,147
# 1    2,450
# 2    2,450
# ...

# %%
df9.to_csv('df9')

# %%
next_search=driver.find_element(By.XPATH,"/html/body/section[2]/section/section[2]/section[1]/div[1]/div/div[1]/div/ul/li[3]/div/p[1]").click()

# %%
Airline_name = []
Depart_time = []
Arival_time = []
Duration = []
Stoppage = []
Price = []
From = []
To = []

#scraping the Airline_name
try:
    air_name = driver.find_elements(By.XPATH,'//span[@class="i-b text ellipsis"]')
    for os in air_name:
        Airline_name.append(os.text)
except NoSuchElementException:
    Airline_name.append('-')

    
#scraping the data of Departure time
try:
    air_dec = driver.find_elements(By.XPATH,'//div[@class="i-b pr"]')
    for os in air_dec:
        Depart_time.append(os.text)
except NoSuchElementException:
    Depart_time.append('-')


#scraping data of the Arival time
try:
    air_ari = driver.find_elements(By.XPATH,'//p[@class="bold fs-15 mb-2 pr time"]')
    for disp in air_ari:
        Arival_time.append(disp.text)
except NoSuchElementException:
    Arival_time.append("-")


# scraping data of Duration of the flight
try:
    dur = driver.find_elements(By.XPATH,'//p[@class="fs-12 bold du mb-2"]')
    for pro in dur:
        Duration.append(pro.text)
except NoSuchElementException:
    Duration.append('-')
    
    
# scraping the number of stoppage
try:
    stop = driver.find_elements(By.XPATH,'//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]')
    for pro in stop:
        Stoppage.append(pro.text)
except NoSuchElementException:
    Stoppage.append('-')
    
    
#scraping the data of fare of
try:
    op_ser = driver.find_elements(By.XPATH,'//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
    for os in op_ser:
        Price.append(os.text)
except NoSuchElementException:
    Price.append('-')
    
    
# scraping  boarding location 
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        From.append(i.text)
except NoSuchElementException:
    From.append('-')
    
    
# scraping  landing location
try:
    name = driver.find_elements(By.XPATH,"//p[2][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        To.append(i.text)
except NoSuchElementException:
    To.append('-')

# %%
df10 = pd.DataFrame()
df10['Airline name']=Airline_name
df10['From']=From
df10['To']=To
df10['Arival time']=Arival_time
df10['Depart time']=Depart_time
df10['Stoppage']=Stoppage
df10['Duration']=Duration
df10['Price']=Price
df10
# Out:
#    Airline name From      To     Arival time Depart time   Stoppage Duration  \
# 0      SpiceJet  Goa  Mumbai           06:25       05:10   Non Stop   1h 15m
# 1        IndiGo  Goa  Mumbai           07:55       06:45   Non Stop   1h 10m
# 2      Air Asia  Goa  Mumbai           04:00       02:55   Non Stop   1h 05m
# 3      Air Asia  Goa  Mumbai           06:55       05:45   Non Stop   1h 10m
# 4      Air Asia  Goa  Mumbai           02:20       01:00   Non Stop   1h 20m
# ..          ...  ...     ...             ...         ...        ...      ...
# 77      Vistara  Goa  Mumbai  16:55\n+ 1 day       14:40  2 Stop(s)  26h 15m
# 78      Vistara  Goa  Mumbai  15:00\n+ 1 day       21:55     1 Stop  17h 05m
# 79      Vistara  Goa  Mumbai  15:00\n+ 1 day       18:25     1 Stop  20h 35m
# 80    Air India  Goa  Mumbai           12:25       01:15     1 Stop  11h 10m
# 81    Air India  Goa  Mumbai           11:20       01:15     1 Stop  10h 05m
#
#      Price
# 0    2,147
# 1    2,450
# ...

# %%
df10.to_csv('df10')

# %%
next_search=driver.find_element(By.XPATH,"/html/body/section[2]/section/section[2]/section[1]/div[1]/div/div[1]/div/ul/li[4]/div/p[1]").click()

# %%
Airline_name = []
Depart_time = []
Arival_time = []
Duration = []
Stoppage = []
Price = []
From = []
To = []

#scraping the Airline_name
try:
    air_name = driver.find_elements(By.XPATH,'//span[@class="i-b text ellipsis"]')
    for os in air_name:
        Airline_name.append(os.text)
except NoSuchElementException:
    Airline_name.append('-')

    
#scraping the data of Departure time
try:
    air_dec = driver.find_elements(By.XPATH,'//div[@class="i-b pr"]')
    for os in air_dec:
        Depart_time.append(os.text)
except NoSuchElementException:
    Depart_time.append('-')


#scraping data of the Arival time
try:
    air_ari = driver.find_elements(By.XPATH,'//p[@class="bold fs-15 mb-2 pr time"]')
    for disp in air_ari:
        Arival_time.append(disp.text)
except NoSuchElementException:
    Arival_time.append("-")


# scraping data of Duration of the flight
try:
    dur = driver.find_elements(By.XPATH,'//p[@class="fs-12 bold du mb-2"]')
    for pro in dur:
        Duration.append(pro.text)
except NoSuchElementException:
    Duration.append('-')
    
    
# scraping the number of stoppage
try:
    stop = driver.find_elements(By.XPATH,'//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]')
    for pro in stop:
        Stoppage.append(pro.text)
except NoSuchElementException:
    Stoppage.append('-')
    
    
#scraping the data of fare of
try:
    op_ser = driver.find_elements(By.XPATH,'//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
    for os in op_ser:
        Price.append(os.text)
except NoSuchElementException:
    Price.append('-')
    
    
# scraping  boarding location 
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        From.append(i.text)
except NoSuchElementException:
    From.append('-')
    
    
# scraping  landing location
try:
    name = driver.find_elements(By.XPATH,"//p[2][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        To.append(i.text)
except NoSuchElementException:
    To.append('-')

# %%
df11 = pd.DataFrame()
df11['Airline name']=Airline_name
df11['From']=From
df11['To']=To
df11['Arival time']=Arival_time
df11['Depart time']=Depart_time
df11['Stoppage']=Stoppage
df11['Duration']=Duration
df11['Price']=Price
df11
# Out:
#    Airline name From      To Arival time Depart time  Stoppage Duration  \
# 0     Air India  Goa  Mumbai       08:10       06:50  Non Stop   1h 20m
# 1      Go First  Goa  Mumbai       08:00       06:40  Non Stop   1h 20m
# 2      Air Asia  Goa  Mumbai       04:00       02:55  Non Stop   1h 05m
# 3      Air Asia  Goa  Mumbai       02:20       01:00  Non Stop   1h 20m
# 4      Air Asia  Goa  Mumbai       06:55       05:45  Non Stop   1h 10m
# ..          ...  ...     ...         ...         ...       ...      ...
# 81      Vistara  Goa  Mumbai       20:15       14:40    1 Stop   5h 35m
# 82      Vistara  Goa  Mumbai       16:30       10:25    1 Stop   6h 05m
# 83      Vistara  Goa  Mumbai       17:35       10:25    1 Stop   7h 10m
# 84    Air India  Goa  Mumbai       12:25       01:15    1 Stop  11h 10m
# 85    Air India  Goa  Mumbai       11:20       01:15    1 Stop  10h 05m
#
#      Price
# 0    3,514
# 1    3,707
# 2    3,719
# 3    3,719
# 4    3,935
# ..     ...
# 81  28,116
# ...

# %%
df11.to_csv('df11')

# %%
driver.close()

# %%
driver=webdriver.Chrome('chromedriver.exe')
driver.maximize_window()

# %%
url = "https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=GOI&destinationCountry=IN&flexi=0&flight_depart_date=21%2F01%2F2023&hb=0&noOfSegments=1&origin=DEL&originCountry=IN&type=O&unique=1674115163442&viewName=normal"
driver.get(url)
time.sleep(5)

# %%
Airline_name = []
Depart_time = []
Arival_time = []
Duration = []
Stoppage = []
Price = []
From = []
To = []

#scraping the Airline_name
try:
    air_name = driver.find_elements(By.XPATH,'//span[@class="i-b text ellipsis"]')
    for os in air_name:
        Airline_name.append(os.text)
except NoSuchElementException:
    Airline_name.append('-')

    
#scraping the data of Departure time
try:
    air_dec = driver.find_elements(By.XPATH,'//div[@class="i-b pr"]')
    for os in air_dec:
        Depart_time.append(os.text)
except NoSuchElementException:
    Depart_time.append('-')


#scraping data of the Arival time
try:
    air_ari = driver.find_elements(By.XPATH,'//p[@class="bold fs-15 mb-2 pr time"]')
    for disp in air_ari:
        Arival_time.append(disp.text)
except NoSuchElementException:
    Arival_time.append("-")


# scraping data of Duration of the flight
try:
    dur = driver.find_elements(By.XPATH,'//p[@class="fs-12 bold du mb-2"]')
    for pro in dur:
        Duration.append(pro.text)
except NoSuchElementException:
    Duration.append('-')
    
    
# scraping the number of stoppage
try:
    stop = driver.find_elements(By.XPATH,'//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]')
    for pro in stop:
        Stoppage.append(pro.text)
except NoSuchElementException:
    Stoppage.append('-')
    
    
#scraping the data of fare of
try:
    op_ser = driver.find_elements(By.XPATH,'//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
    for os in op_ser:
        Price.append(os.text)
except NoSuchElementException:
    Price.append('-')
    
    
# scraping  boarding location 
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        From.append(i.text)
except NoSuchElementException:
    From.append('-')
    
    
# scraping  landing location
try:
    name = driver.find_elements(By.XPATH,"//p[2][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        To.append(i.text)
except NoSuchElementException:
    To.append('-')

# %%
df12 = pd.DataFrame()
df12['Airline name']=Airline_name
df12['From']=From
df12['To']=To
df12['Arival time']=Arival_time
df12['Depart time']=Depart_time
df12['Stoppage']=Stoppage
df12['Duration']=Duration
df12['Price']=Price
df12
# Out:
#     Airline name       From   To     Arival time Depart time  Stoppage  \
# 0       Air Asia  New Delhi  Goa  05:25\n+ 1 day       21:20    1 Stop
# 1       Air Asia  New Delhi  Goa  06:45\n+ 1 day       21:20    1 Stop
# 2       Air Asia  New Delhi  Goa  05:25\n+ 1 day       19:05    1 Stop
# 3       Air Asia  New Delhi  Goa           17:35       07:10    1 Stop
# 4       Go First  New Delhi  Goa           12:45       05:15    1 Stop
# ..           ...        ...  ...             ...         ...       ...
# 126     Air Asia  New Delhi  Goa           15:25       12:45  Non Stop
# 127    Air India  New Delhi  Goa           22:20       10:00    1 Stop
# 128    Air India  New Delhi  Goa           14:45       10:00    1 Stop
# 129    Air India  New Delhi  Goa           22:20       09:00    1 Stop
# 130    Air India  New Delhi  Goa           14:45       09:00    1 Stop
#
#     Duration   Price
# 0     8h 05m   6,287
# 1     9h 25m   6,287
# 2    10h 20m   6,287
# 3    10h 25m   6,287
# ...

# %%
df12.to_csv('df12')

# %%
next_search=driver.find_element(By.XPATH,"/html/body/section[2]/section/section[2]/section[1]/div[1]/div/div[1]/div/ul/li[4]/div/p[1]").click()

# %%
Airline_name = []
Depart_time = []
Arival_time = []
Duration = []
Stoppage = []
Price = []
From = []
To = []

#scraping the Airline_name
try:
    air_name = driver.find_elements(By.XPATH,'//span[@class="i-b text ellipsis"]')
    for os in air_name:
        Airline_name.append(os.text)
except NoSuchElementException:
    Airline_name.append('-')

    
#scraping the data of Departure time
try:
    air_dec = driver.find_elements(By.XPATH,'//div[@class="i-b pr"]')
    for os in air_dec:
        Depart_time.append(os.text)
except NoSuchElementException:
    Depart_time.append('-')


#scraping data of the Arival time
try:
    air_ari = driver.find_elements(By.XPATH,'//p[@class="bold fs-15 mb-2 pr time"]')
    for disp in air_ari:
        Arival_time.append(disp.text)
except NoSuchElementException:
    Arival_time.append("-")


# scraping data of Duration of the flight
try:
    dur = driver.find_elements(By.XPATH,'//p[@class="fs-12 bold du mb-2"]')
    for pro in dur:
        Duration.append(pro.text)
except NoSuchElementException:
    Duration.append('-')
    
    
# scraping the number of stoppage
try:
    stop = driver.find_elements(By.XPATH,'//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]')
    for pro in stop:
        Stoppage.append(pro.text)
except NoSuchElementException:
    Stoppage.append('-')
    
    
#scraping the data of fare of
try:
    op_ser = driver.find_elements(By.XPATH,'//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
    for os in op_ser:
        Price.append(os.text)
except NoSuchElementException:
    Price.append('-')
    
    
# scraping  boarding location 
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        From.append(i.text)
except NoSuchElementException:
    From.append('-')
    
    
# scraping  landing location
try:
    name = driver.find_elements(By.XPATH,"//p[2][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        To.append(i.text)
except NoSuchElementException:
    To.append('-')

# %%
df13 = pd.DataFrame()
df13['Airline name']=Airline_name
df13['From']=From
df13['To']=To
df13['Arival time']=Arival_time
df13['Depart time']=Depart_time
df13['Stoppage']=Stoppage
df13['Duration']=Duration
df13['Price']=Price
df13
# Out:
#     Airline name       From   To     Arival time Depart time  Stoppage  \
# 0       Air Asia  New Delhi  Goa  05:25\n+ 1 day       21:20    1 Stop
# 1       Air Asia  New Delhi  Goa  06:45\n+ 1 day       21:20    1 Stop
# 2       Air Asia  New Delhi  Goa           17:35       07:10    1 Stop
# 3       Go First  New Delhi  Goa  00:05\n+ 1 day       21:30  Non Stop
# 4      Air India  New Delhi  Goa  00:40\n+ 1 day       22:00  Non Stop
# ..           ...        ...  ...             ...         ...       ...
# 128      Vistara  New Delhi  Goa           14:05       09:05    1 Stop
# 129    Air India  New Delhi  Goa           14:45       10:00    1 Stop
# 130      Vistara  New Delhi  Goa  14:05\n+ 1 day       16:05    1 Stop
# 131    Air India  New Delhi  Goa           17:45       09:45    1 Stop
# 132      Vistara  New Delhi  Goa  14:05\n+ 1 day       14:10    1 Stop
#
#     Duration   Price
# 0     8h 05m   6,287
# 1     9h 25m   6,287
# 2    10h 25m   6,287
# 3     2h 35m   6,513
# ...

# %%
df13.to_csv('df13')

# %%
next_search=driver.find_element(By.XPATH,"/html/body/section[1]/section/div/div/form/ul[2]/li[2]/i").click()

# %%
next_search=driver.find_element(By.XPATH,"/html/body/section[1]/section/div/div/form/div[1]/div/button").click()

# %%
Airline_name = []
Depart_time = []
Arival_time = []
Duration = []
Stoppage = []
Price = []
From = []
To = []

#scraping the Airline_name
try:
    air_name = driver.find_elements(By.XPATH,'//span[@class="i-b text ellipsis"]')
    for os in air_name:
        Airline_name.append(os.text)
except NoSuchElementException:
    Airline_name.append('-')

    
#scraping the data of Departure time
try:
    air_dec = driver.find_elements(By.XPATH,'//div[@class="i-b pr"]')
    for os in air_dec:
        Depart_time.append(os.text)
except NoSuchElementException:
    Depart_time.append('-')


#scraping data of the Arival time
try:
    air_ari = driver.find_elements(By.XPATH,'//p[@class="bold fs-15 mb-2 pr time"]')
    for disp in air_ari:
        Arival_time.append(disp.text)
except NoSuchElementException:
    Arival_time.append("-")


# scraping data of Duration of the flight
try:
    dur = driver.find_elements(By.XPATH,'//p[@class="fs-12 bold du mb-2"]')
    for pro in dur:
        Duration.append(pro.text)
except NoSuchElementException:
    Duration.append('-')
    
    
# scraping the number of stoppage
try:
    stop = driver.find_elements(By.XPATH,'//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]')
    for pro in stop:
        Stoppage.append(pro.text)
except NoSuchElementException:
    Stoppage.append('-')
    
    
#scraping the data of fare of
try:
    op_ser = driver.find_elements(By.XPATH,'//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
    for os in op_ser:
        Price.append(os.text)
except NoSuchElementException:
    Price.append('-')
    
    
# scraping  boarding location 
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        From.append(i.text)
except NoSuchElementException:
    From.append('-')
    
    
# scraping  landing location
try:
    name = driver.find_elements(By.XPATH,"//p[2][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        To.append(i.text)
except NoSuchElementException:
    To.append('-')

# %%
df14 = pd.DataFrame()
df14['Airline name']=Airline_name
df14['From']=From
df14['To']=To
df14['Arival time']=Arival_time
df14['Depart time']=Depart_time
df14['Stoppage']=Stoppage
df14['Duration']=Duration
df14['Price']=Price
df14
# Out:
#     Airline name From         To     Arival time Depart time  Stoppage  \
# 0       Go First  Goa  New Delhi           03:00       00:35  Non Stop
# 1       Air Asia  Goa  New Delhi           15:00       08:10    1 Stop
# 2         IndiGo  Goa  New Delhi           22:55       17:10    1 Stop
# 3       Air Asia  Goa  New Delhi  00:35\n+ 1 day       18:05    1 Stop
# 4         IndiGo  Goa  New Delhi  00:25\n+ 1 day       18:30    1 Stop
# ..           ...  ...        ...             ...         ...       ...
# 129    Air India  Goa  New Delhi           12:50       04:20    1 Stop
# 130    Air India  Goa  New Delhi           15:55       04:20    1 Stop
# 131    Air India  Goa  New Delhi           20:00       04:20    1 Stop
# 132      Vistara  Goa  New Delhi           20:30       14:40    1 Stop
# 133      Vistara  Goa  New Delhi           22:20       14:40    1 Stop
#
#     Duration   Price
# 0     2h 25m   7,103
# 1     6h 50m   7,295
# 2     5h 45m   8,008
# 3     6h 30m   8,565
# ...

# %%
df14.to_csv('df14')

# %%
next_search=driver.find_element(By.XPATH,"/html/body/section[2]/section/section[2]/section[1]/div[1]/div/div[1]/div/ul/li[5]/div/p[1]").click()

# %%
Airline_name = []
Depart_time = []
Arival_time = []
Duration = []
Stoppage = []
Price = []
From = []
To = []

#scraping the Airline_name
try:
    air_name = driver.find_elements(By.XPATH,'//span[@class="i-b text ellipsis"]')
    for os in air_name:
        Airline_name.append(os.text)
except NoSuchElementException:
    Airline_name.append('-')

    
#scraping the data of Departure time
try:
    air_dec = driver.find_elements(By.XPATH,'//div[@class="i-b pr"]')
    for os in air_dec:
        Depart_time.append(os.text)
except NoSuchElementException:
    Depart_time.append('-')


#scraping data of the Arival time
try:
    air_ari = driver.find_elements(By.XPATH,'//p[@class="bold fs-15 mb-2 pr time"]')
    for disp in air_ari:
        Arival_time.append(disp.text)
except NoSuchElementException:
    Arival_time.append("-")


# scraping data of Duration of the flight
try:
    dur = driver.find_elements(By.XPATH,'//p[@class="fs-12 bold du mb-2"]')
    for pro in dur:
        Duration.append(pro.text)
except NoSuchElementException:
    Duration.append('-')
    
    
# scraping the number of stoppage
try:
    stop = driver.find_elements(By.XPATH,'//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]')
    for pro in stop:
        Stoppage.append(pro.text)
except NoSuchElementException:
    Stoppage.append('-')
    
    
#scraping the data of fare of
try:
    op_ser = driver.find_elements(By.XPATH,'//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
    for os in op_ser:
        Price.append(os.text)
except NoSuchElementException:
    Price.append('-')
    
    
# scraping  boarding location 
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        From.append(i.text)
except NoSuchElementException:
    From.append('-')
    
    
# scraping  landing location
try:
    name = driver.find_elements(By.XPATH,"//p[2][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        To.append(i.text)
except NoSuchElementException:
    To.append('-')

# %%
df15 = pd.DataFrame()
df15['Airline name']=Airline_name
df15['From']=From
df15['To']=To
df15['Arival time']=Arival_time
df15['Depart time']=Depart_time
df15['Stoppage']=Stoppage
df15['Duration']=Duration
df15['Price']=Price
df15
# Out:
#     Airline name From         To     Arival time Depart time  Stoppage  \
# 0         IndiGo  Goa  New Delhi  05:45\n+ 1 day       23:15    1 Stop
# 1       Air Asia  Goa  New Delhi           20:45       14:45    1 Stop
# 2       Air Asia  Goa  New Delhi           14:20       08:10    1 Stop
# 3       Air Asia  Goa  New Delhi  00:35\n+ 1 day       18:05    1 Stop
# 4       Air Asia  Goa  New Delhi           15:00       08:10    1 Stop
# ..           ...  ...        ...             ...         ...       ...
# 128     Air Asia  Goa  New Delhi           19:10       16:35  Non Stop
# 129       IndiGo  Goa  New Delhi           20:50       15:05    1 Stop
# 130       IndiGo  Goa  New Delhi           14:50       08:05    1 Stop
# 131    Air India  Goa  New Delhi           03:50       01:15  Non Stop
# 132    Air India  Goa  New Delhi           12:50       04:20    1 Stop
#
#     Duration   Price
# 0     6h 30m   7,210
# 1     6h 00m   7,295
# 2     6h 10m   7,295
# 3     6h 30m   7,295
# ...

# %%
df15.to_csv('df15')

# %%
driver.close()

# %%
driver=webdriver.Chrome('chromedriver.exe')
driver.maximize_window()

# %%
url = "https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=BLR&destinationCountry=IN&flexi=0&flight_depart_date=19%2F01%2F2023&hb=0&noOfSegments=1&origin=DEL&originCountry=IN&type=O&unique=1299897853199&version=1.6&viewName=normal"
driver.get(url)
time.sleep(5)

# %%
Airline_name = []
Depart_time = []
Arival_time = []
Duration = []
Stoppage = []
Price = []
From = []
To = []

#scraping the Airline_name
try:
    air_name = driver.find_elements(By.XPATH,'//span[@class="i-b text ellipsis"]')
    for os in air_name:
        Airline_name.append(os.text)
except NoSuchElementException:
    Airline_name.append('-')

    
#scraping the data of Departure time
try:
    air_dec = driver.find_elements(By.XPATH,'//div[@class="i-b pr"]')
    for os in air_dec:
        Depart_time.append(os.text)
except NoSuchElementException:
    Depart_time.append('-')


#scraping data of the Arival time
try:
    air_ari = driver.find_elements(By.XPATH,'//p[@class="bold fs-15 mb-2 pr time"]')
    for disp in air_ari:
        Arival_time.append(disp.text)
except NoSuchElementException:
    Arival_time.append("-")


# scraping data of Duration of the flight
try:
    dur = driver.find_elements(By.XPATH,'//p[@class="fs-12 bold du mb-2"]')
    for pro in dur:
        Duration.append(pro.text)
except NoSuchElementException:
    Duration.append('-')
    
    
# scraping the number of stoppage
try:
    stop = driver.find_elements(By.XPATH,'//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]')
    for pro in stop:
        Stoppage.append(pro.text)
except NoSuchElementException:
    Stoppage.append('-')
    
    
#scraping the data of fare of
try:
    op_ser = driver.find_elements(By.XPATH,'//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
    for os in op_ser:
        Price.append(os.text)
except NoSuchElementException:
    Price.append('-')
    
    
# scraping  boarding location 
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        From.append(i.text)
except NoSuchElementException:
    From.append('-')
    
    
# scraping  landing location
try:
    name = driver.find_elements(By.XPATH,"//p[2][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        To.append(i.text)
except NoSuchElementException:
    To.append('-')

# %%
df16 = pd.DataFrame()
df16['Airline name']=Airline_name
df16['From']=From
df16['To']=To
df16['Arival time']=Arival_time
df16['Depart time']=Depart_time
df16['Stoppage']=Stoppage
df16['Duration']=Duration
df16['Price']=Price
df16
# Out:
#    Airline name       From         To     Arival time Depart time  Stoppage  \
# 0      Air Asia  New Delhi  Bangalore           21:45       19:05  Non Stop
# 1      Air Asia  New Delhi  Bangalore  00:25\n+ 1 day       21:20  Non Stop
# 2        IndiGo  New Delhi  Bangalore  00:35\n+ 1 day       21:45  Non Stop
# 3        IndiGo  New Delhi  Bangalore  01:45\n+ 1 day       22:55  Non Stop
# 4        IndiGo  New Delhi  Bangalore           23:25       20:30  Non Stop
# ..          ...        ...        ...             ...         ...       ...
# 73      Vistara  New Delhi  Bangalore  15:55\n+ 1 day       18:40    1 Stop
# 74      Vistara  New Delhi  Bangalore  22:45\n+ 1 day       20:40    1 Stop
# 75      Vistara  New Delhi  Bangalore  09:50\n+ 1 day       17:35    1 Stop
# 76      Vistara  New Delhi  Bangalore           21:30       17:35    1 Stop
# 77     SpiceJet  New Delhi  Bangalore  00:15\n+ 1 day       16:50    1 Stop
#
#    Duration   Price
# 0    2h 40m   5,235
# ...

# %%
df16.to_csv('df16')

# %%
next_search=driver.find_element(By.XPATH,"/html/body/section[2]/section/section[2]/section[1]/div[1]/div/div[1]/div/ul/li[2]/div/p[1]").click()

# %%
Airline_name = []
Depart_time = []
Arival_time = []
Duration = []
Stoppage = []
Price = []
From = []
To = []

#scraping the Airline_name
try:
    air_name = driver.find_elements(By.XPATH,'//span[@class="i-b text ellipsis"]')
    for os in air_name:
        Airline_name.append(os.text)
except NoSuchElementException:
    Airline_name.append('-')

    
#scraping the data of Departure time
try:
    air_dec = driver.find_elements(By.XPATH,'//div[@class="i-b pr"]')
    for os in air_dec:
        Depart_time.append(os.text)
except NoSuchElementException:
    Depart_time.append('-')


#scraping data of the Arival time
try:
    air_ari = driver.find_elements(By.XPATH,'//p[@class="bold fs-15 mb-2 pr time"]')
    for disp in air_ari:
        Arival_time.append(disp.text)
except NoSuchElementException:
    Arival_time.append("-")


# scraping data of Duration of the flight
try:
    dur = driver.find_elements(By.XPATH,'//p[@class="fs-12 bold du mb-2"]')
    for pro in dur:
        Duration.append(pro.text)
except NoSuchElementException:
    Duration.append('-')
    
    
# scraping the number of stoppage
try:
    stop = driver.find_elements(By.XPATH,'//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]')
    for pro in stop:
        Stoppage.append(pro.text)
except NoSuchElementException:
    Stoppage.append('-')
    
    
#scraping the data of fare of
try:
    op_ser = driver.find_elements(By.XPATH,'//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
    for os in op_ser:
        Price.append(os.text)
except NoSuchElementException:
    Price.append('-')
    
    
# scraping  boarding location 
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        From.append(i.text)
except NoSuchElementException:
    From.append('-')
    
    
# scraping  landing location
try:
    name = driver.find_elements(By.XPATH,"//p[2][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        To.append(i.text)
except NoSuchElementException:
    To.append('-')

# %%
df17 = pd.DataFrame()
df17['Airline name']=Airline_name
df17['From']=From
df17['To']=To
df17['Arival time']=Arival_time
df17['Depart time']=Depart_time
df17['Stoppage']=Stoppage
df17['Duration']=Duration
df17['Price']=Price
df17
# Out:
#     Airline name       From         To     Arival time Depart time  Stoppage  \
# 0         IndiGo  New Delhi  Bangalore           07:15       04:20  Non Stop
# 1       Go First  New Delhi  Bangalore           08:35       05:45  Non Stop
# 2       Air Asia  New Delhi  Bangalore           12:10       07:10    1 Stop
# 3         IndiGo  New Delhi  Bangalore           08:45       05:55  Non Stop
# 4         IndiGo  New Delhi  Bangalore           09:50       07:00  Non Stop
# ..           ...        ...        ...             ...         ...       ...
# 148    Air India  New Delhi  Bangalore  11:05\n+ 1 day       17:50    1 Stop
# 149    Air India  New Delhi  Bangalore           20:30       14:00    1 Stop
# 150    Air India  New Delhi  Bangalore  08:30\n+ 1 day       19:00    1 Stop
# 151    Air India  New Delhi  Bangalore  08:30\n+ 1 day       17:50    1 Stop
# 152    Air India  New Delhi  Bangalore  08:30\n+ 1 day       14:00    1 Stop
#
#     Duration   Price
# 0     2h 55m   5,237
# ...

# %%
df17.to_csv('df17')

# %%
next_search=driver.find_element(By.XPATH,"/html/body/section[2]/section/section[2]/section[1]/div[1]/div/div[1]/div/ul/li[3]/div/p[1]").click()

# %%
Airline_name = []
Depart_time = []
Arival_time = []
Duration = []
Stoppage = []
Price = []
From = []
To = []

#scraping the Airline_name
try:
    air_name = driver.find_elements(By.XPATH,'//span[@class="i-b text ellipsis"]')
    for os in air_name:
        Airline_name.append(os.text)
except NoSuchElementException:
    Airline_name.append('-')

    
#scraping the data of Departure time
try:
    air_dec = driver.find_elements(By.XPATH,'//div[@class="i-b pr"]')
    for os in air_dec:
        Depart_time.append(os.text)
except NoSuchElementException:
    Depart_time.append('-')


#scraping data of the Arival time
try:
    air_ari = driver.find_elements(By.XPATH,'//p[@class="bold fs-15 mb-2 pr time"]')
    for disp in air_ari:
        Arival_time.append(disp.text)
except NoSuchElementException:
    Arival_time.append("-")


# scraping data of Duration of the flight
try:
    dur = driver.find_elements(By.XPATH,'//p[@class="fs-12 bold du mb-2"]')
    for pro in dur:
        Duration.append(pro.text)
except NoSuchElementException:
    Duration.append('-')
    
    
# scraping the number of stoppage
try:
    stop = driver.find_elements(By.XPATH,'//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]')
    for pro in stop:
        Stoppage.append(pro.text)
except NoSuchElementException:
    Stoppage.append('-')
    
    
#scraping the data of fare of
try:
    op_ser = driver.find_elements(By.XPATH,'//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
    for os in op_ser:
        Price.append(os.text)
except NoSuchElementException:
    Price.append('-')
    
    
# scraping  boarding location 
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        From.append(i.text)
except NoSuchElementException:
    From.append('-')
    
    
# scraping  landing location
try:
    name = driver.find_elements(By.XPATH,"//p[2][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        To.append(i.text)
except NoSuchElementException:
    To.append('-')

# %%
df18 = pd.DataFrame()
df18['Airline name']=Airline_name
df18['From']=From
df18['To']=To
df18['Arival time']=Arival_time
df18['Depart time']=Depart_time
df18['Stoppage']=Stoppage
df18['Duration']=Duration
df18['Price']=Price
df18
# Out:
#     Airline name       From         To     Arival time Depart time  Stoppage  \
# 0         IndiGo  New Delhi  Bangalore  00:35\n+ 1 day       21:45  Non Stop
# 1        Vistara  New Delhi  Bangalore           23:55       21:30  Non Stop
# 2      Air India  New Delhi  Bangalore           08:55       06:10  Non Stop
# 3        Vistara  New Delhi  Bangalore           22:40       19:55  Non Stop
# 4      Air India  New Delhi  Bangalore  00:05\n+ 1 day       21:10  Non Stop
# ..           ...        ...        ...             ...         ...       ...
# 153      Vistara  New Delhi  Bangalore  15:55\n+ 1 day       18:40    1 Stop
# 154     Air Asia  New Delhi  Bangalore           15:05       07:15    1 Stop
# 155      Vistara  New Delhi  Bangalore  00:50\n+ 1 day       14:10    1 Stop
# 156      Vistara  New Delhi  Bangalore           21:30       10:20    1 Stop
# 157    Air India  New Delhi  Bangalore           18:25       09:00    1 Stop
#
#     Duration   Price
# 0     2h 50m   6,217
# ...

# %%
df18.to_csv('df18')

# %%
next_search=driver.find_element(By.XPATH,"/html/body/section[1]/section/div/div/form/ul[2]/li[2]/i").click()

# %%
next_search=driver.find_element(By.XPATH,"/html/body/section[1]/section/div/div/form/div[1]/div/button").click()

# %%
Airline_name = []
Depart_time = []
Arival_time = []
Duration = []
Stoppage = []
Price = []
From = []
To = []

#scraping the Airline_name
try:
    air_name = driver.find_elements(By.XPATH,'//span[@class="i-b text ellipsis"]')
    for os in air_name:
        Airline_name.append(os.text)
except NoSuchElementException:
    Airline_name.append('-')

    
#scraping the data of Departure time
try:
    air_dec = driver.find_elements(By.XPATH,'//div[@class="i-b pr"]')
    for os in air_dec:
        Depart_time.append(os.text)
except NoSuchElementException:
    Depart_time.append('-')


#scraping data of the Arival time
try:
    air_ari = driver.find_elements(By.XPATH,'//p[@class="bold fs-15 mb-2 pr time"]')
    for disp in air_ari:
        Arival_time.append(disp.text)
except NoSuchElementException:
    Arival_time.append("-")


# scraping data of Duration of the flight
try:
    dur = driver.find_elements(By.XPATH,'//p[@class="fs-12 bold du mb-2"]')
    for pro in dur:
        Duration.append(pro.text)
except NoSuchElementException:
    Duration.append('-')
    
    
# scraping the number of stoppage
try:
    stop = driver.find_elements(By.XPATH,'//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]')
    for pro in stop:
        Stoppage.append(pro.text)
except NoSuchElementException:
    Stoppage.append('-')
    
    
#scraping the data of fare of
try:
    op_ser = driver.find_elements(By.XPATH,'//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
    for os in op_ser:
        Price.append(os.text)
except NoSuchElementException:
    Price.append('-')
    
    
# scraping  boarding location 
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        From.append(i.text)
except NoSuchElementException:
    From.append('-')
    
    
# scraping  landing location
try:
    name = driver.find_elements(By.XPATH,"//p[2][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        To.append(i.text)
except NoSuchElementException:
    To.append('-')

# %%
df19 = pd.DataFrame()
df19['Airline name']=Airline_name
df19['From']=From
df19['To']=To
df19['Arival time']=Arival_time
df19['Depart time']=Depart_time
df19['Stoppage']=Stoppage
df19['Duration']=Duration
df19['Price']=Price
df19
# Out:
#     Airline name       From         To     Arival time Depart time  Stoppage  \
# 0       Air Asia  Bangalore  New Delhi           19:45       12:15    1 Stop
# 1         IndiGo  Bangalore  New Delhi  02:10\n+ 1 day       23:20  Non Stop
# 2         IndiGo  Bangalore  New Delhi  01:00\n+ 1 day       22:00  Non Stop
# 3       Air Asia  Bangalore  New Delhi  01:25\n+ 1 day       22:40  Non Stop
# 4         IndiGo  Bangalore  New Delhi  07:30\n+ 1 day       23:40    1 Stop
# ..           ...        ...        ...             ...         ...       ...
# 145      Vistara  Bangalore  New Delhi           14:10       11:30  Non Stop
# 146    Air India  Bangalore  New Delhi           15:55       13:15  Non Stop
# 147      Vistara  Bangalore  New Delhi           20:30       17:50  Non Stop
# 148      Vistara  Bangalore  New Delhi           12:35       09:45  Non Stop
# 149       IndiGo  Bangalore  New Delhi  07:20\n+ 1 day       22:30    1 Stop
#
#     Duration   Price
# 0     7h 30m   7,094
# ...

# %%
df19.to_csv('df19')

# %%
driver.close()

# %%
driver=webdriver.Chrome('chromedriver.exe')
driver.maximize_window()

# %%
url = "https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=DEL&destinationCountry=IN&flexi=0&flight_depart_date=19%2F01%2F2023&hb=0&noOfSegments=1&origin=CCU&originCountry=IN&type=O&unique=359913201877&version=1.1&viewName=normal"
driver.get(url)
time.sleep(5)

# %%
Airline_name = []
Depart_time = []
Arival_time = []
Duration = []
Stoppage = []
Price = []
From = []
To = []

#scraping the Airline_name
try:
    air_name = driver.find_elements(By.XPATH,'//span[@class="i-b text ellipsis"]')
    for os in air_name:
        Airline_name.append(os.text)
except NoSuchElementException:
    Airline_name.append('-')

    
#scraping the data of Departure time
try:
    air_dec = driver.find_elements(By.XPATH,'//div[@class="i-b pr"]')
    for os in air_dec:
        Depart_time.append(os.text)
except NoSuchElementException:
    Depart_time.append('-')


#scraping data of the Arival time
try:
    air_ari = driver.find_elements(By.XPATH,'//p[@class="bold fs-15 mb-2 pr time"]')
    for disp in air_ari:
        Arival_time.append(disp.text)
except NoSuchElementException:
    Arival_time.append("-")


# scraping data of Duration of the flight
try:
    dur = driver.find_elements(By.XPATH,'//p[@class="fs-12 bold du mb-2"]')
    for pro in dur:
        Duration.append(pro.text)
except NoSuchElementException:
    Duration.append('-')
    
    
# scraping the number of stoppage
try:
    stop = driver.find_elements(By.XPATH,'//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]')
    for pro in stop:
        Stoppage.append(pro.text)
except NoSuchElementException:
    Stoppage.append('-')
    
    
#scraping the data of fare of
try:
    op_ser = driver.find_elements(By.XPATH,'//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
    for os in op_ser:
        Price.append(os.text)
except NoSuchElementException:
    Price.append('-')
    
    
# scraping  boarding location 
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        From.append(i.text)
except NoSuchElementException:
    From.append('-')
    
    
# scraping  landing location
try:
    name = driver.find_elements(By.XPATH,"//p[2][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        To.append(i.text)
except NoSuchElementException:
    To.append('-')

# %%
df20 = pd.DataFrame()
df20['Airline name']=Airline_name
df20['From']=From
df20['To']=To
df20['Arival time']=Arival_time
df20['Depart time']=Depart_time
df20['Stoppage']=Stoppage
df20['Duration']=Duration
df20['Price']=Price
df20
# Out:
#    Airline name     From         To      Arival time Depart time   Stoppage  \
# 0      Air Asia  Kolkata  New Delhi   03:55\n+ 1 day       20:15     1 Stop
# 1      Air Asia  Kolkata  New Delhi   01:40\n+ 1 day       16:10     1 Stop
# 2        IndiGo  Kolkata  New Delhi            23:15       20:45   Non Stop
# 3        IndiGo  Kolkata  New Delhi   00:30\n+ 1 day       21:55   Non Stop
# 4        IndiGo  Kolkata  New Delhi            22:10       17:35     1 Stop
# 5        IndiGo  Kolkata  New Delhi            23:30       17:35     1 Stop
# 6        IndiGo  Kolkata  New Delhi            22:25       16:45     1 Stop
# 7       Vistara  Kolkata  New Delhi            21:10       18:45   Non Stop
# 8        IndiGo  Kolkata  New Delhi            22:15       19:35   Non Stop
# 9        IndiGo  Kolkata  New Delhi            20:50       18:20   Non Stop
# 10      Vistara  Kolkata  New Delhi            22:45       20:25   Non Stop
# ...

# %%
df20.to_csv('df20')

# %%
next_search=driver.find_element(By.XPATH,"/html/body/section[2]/section/section[2]/section[1]/div[1]/div/div[1]/div/ul/li[2]/div/p[1]").click()

# %%
Airline_name = []
Depart_time = []
Arival_time = []
Duration = []
Stoppage = []
Price = []
From = []
To = []

#scraping the Airline_name
try:
    air_name = driver.find_elements(By.XPATH,'//span[@class="i-b text ellipsis"]')
    for os in air_name:
        Airline_name.append(os.text)
except NoSuchElementException:
    Airline_name.append('-')

    
#scraping the data of Departure time
try:
    air_dec = driver.find_elements(By.XPATH,'//div[@class="i-b pr"]')
    for os in air_dec:
        Depart_time.append(os.text)
except NoSuchElementException:
    Depart_time.append('-')


#scraping data of the Arival time
try:
    air_ari = driver.find_elements(By.XPATH,'//p[@class="bold fs-15 mb-2 pr time"]')
    for disp in air_ari:
        Arival_time.append(disp.text)
except NoSuchElementException:
    Arival_time.append("-")


# scraping data of Duration of the flight
try:
    dur = driver.find_elements(By.XPATH,'//p[@class="fs-12 bold du mb-2"]')
    for pro in dur:
        Duration.append(pro.text)
except NoSuchElementException:
    Duration.append('-')
    
    
# scraping the number of stoppage
try:
    stop = driver.find_elements(By.XPATH,'//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]')
    for pro in stop:
        Stoppage.append(pro.text)
except NoSuchElementException:
    Stoppage.append('-')
    
    
#scraping the data of fare of
try:
    op_ser = driver.find_elements(By.XPATH,'//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
    for os in op_ser:
        Price.append(os.text)
except NoSuchElementException:
    Price.append('-')
    
    
# scraping  boarding location 
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        From.append(i.text)
except NoSuchElementException:
    From.append('-')
    
    
# scraping  landing location
try:
    name = driver.find_elements(By.XPATH,"//p[2][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        To.append(i.text)
except NoSuchElementException:
    To.append('-')

# %%
df21 = pd.DataFrame()
df21['Airline name']=Airline_name
df21['From']=From
df21['To']=To
df21['Arival time']=Arival_time
df21['Depart time']=Depart_time
df21['Stoppage']=Stoppage
df21['Duration']=Duration
df21['Price']=Price
df21
# Out:
#     Airline name     From         To     Arival time Depart time   Stoppage  \
# 0       Air Asia  Kolkata  New Delhi  01:40\n+ 1 day       16:10     1 Stop
# 1       Air Asia  Kolkata  New Delhi  01:40\n+ 1 day       13:20     1 Stop
# 2       Air Asia  Kolkata  New Delhi           22:15       08:10     1 Stop
# 3         IndiGo  Kolkata  New Delhi           07:55       05:30   Non Stop
# 4         IndiGo  Kolkata  New Delhi           23:30       17:35     1 Stop
# ..           ...      ...        ...             ...         ...        ...
# 99       Vistara  Kolkata  New Delhi           21:55       10:20     1 Stop
# 100      Vistara  Kolkata  New Delhi           23:00       10:20     1 Stop
# 101    Air India  Kolkata  New Delhi  09:15\n+ 1 day       17:15     1 Stop
# 102      Vistara  Kolkata  New Delhi           21:25       10:20  2 Stop(s)
# 103      Vistara  Kolkata  New Delhi           22:20       10:20  2 Stop(s)
#
#     Duration   Price
# 0     9h 30m   7,423
# ...

# %%
df21.to_csv('df21')

# %%
next_search=driver.find_element(By.XPATH,"/html/body/section[1]/section/div/div/form/ul[2]/li[2]/i").click()

# %%
next_search=driver.find_element(By.XPATH,"/html/body/section[1]/section/div/div/form/div[1]/div/button/span").click()

# %%
Airline_name = []
Depart_time = []
Arival_time = []
Duration = []
Stoppage = []
Price = []
From = []
To = []

#scraping the Airline_name
try:
    air_name = driver.find_elements(By.XPATH,'//span[@class="i-b text ellipsis"]')
    for os in air_name:
        Airline_name.append(os.text)
except NoSuchElementException:
    Airline_name.append('-')

    
#scraping the data of Departure time
try:
    air_dec = driver.find_elements(By.XPATH,'//div[@class="i-b pr"]')
    for os in air_dec:
        Depart_time.append(os.text)
except NoSuchElementException:
    Depart_time.append('-')


#scraping data of the Arival time
try:
    air_ari = driver.find_elements(By.XPATH,'//p[@class="bold fs-15 mb-2 pr time"]')
    for disp in air_ari:
        Arival_time.append(disp.text)
except NoSuchElementException:
    Arival_time.append("-")


# scraping data of Duration of the flight
try:
    dur = driver.find_elements(By.XPATH,'//p[@class="fs-12 bold du mb-2"]')
    for pro in dur:
        Duration.append(pro.text)
except NoSuchElementException:
    Duration.append('-')
    
    
# scraping the number of stoppage
try:
    stop = driver.find_elements(By.XPATH,'//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]')
    for pro in stop:
        Stoppage.append(pro.text)
except NoSuchElementException:
    Stoppage.append('-')
    
    
#scraping the data of fare of
try:
    op_ser = driver.find_elements(By.XPATH,'//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
    for os in op_ser:
        Price.append(os.text)
except NoSuchElementException:
    Price.append('-')
    
    
# scraping  boarding location 
try:
    name = driver.find_elements(By.XPATH,"//p[1][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        From.append(i.text)
except NoSuchElementException:
    From.append('-')
    
    
# scraping  landing location
try:
    name = driver.find_elements(By.XPATH,"//p[2][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
    for i in name:
        To.append(i.text)
except NoSuchElementException:
    To.append('-')

# %%
df22 = pd.DataFrame()
df22['Airline name']=Airline_name
df22['From']=From
df22['To']=To
df22['Arival time']=Arival_time
df22['Depart time']=Depart_time
df22['Stoppage']=Stoppage
df22['Duration']=Duration
df22['Price']=Price
df22
# Out:
#     Airline name       From       To     Arival time Depart time   Stoppage  \
# 0       SpiceJet  New Delhi  Kolkata           07:45       05:45   Non Stop
# 1       SpiceJet  New Delhi  Kolkata  10:25\n+ 1 day       08:30     1 Stop
# 2       Air Asia  New Delhi  Kolkata           12:35       07:10     1 Stop
# 3       Air Asia  New Delhi  Kolkata  02:30\n+ 1 day       15:05     1 Stop
# 4       Air Asia  New Delhi  Kolkata  12:35\n+ 1 day       21:45     1 Stop
# ..           ...        ...      ...             ...         ...        ...
# 98       Vistara  New Delhi  Kolkata  09:40\n+ 1 day       17:35  2 Stop(s)
# 99       Vistara  New Delhi  Kolkata           16:50       09:30     1 Stop
# 100      Vistara  New Delhi  Kolkata           19:50       09:30     1 Stop
# 101    Air India  New Delhi  Kolkata           23:00       14:00     1 Stop
# 102      Vistara  New Delhi  Kolkata  09:40\n+ 1 day       18:40  2 Stop(s)
#
#     Duration   Price
# 0     2h 00m   4,796
# ...

# %%
df22.to_csv('df22')

# %%
data1= pd.read_csv("df1")
data2= pd.read_csv("df2")
data3= pd.read_csv("df3")
data4= pd.read_csv("df4")
data5= pd.read_csv("df5")
data6= pd.read_csv("df6")
data7= pd.read_csv("df7")
data8= pd.read_csv("df8")
data9= pd.read_csv("df9")
data10= pd.read_csv("df10")
data11= pd.read_csv("df11")
data12= pd.read_csv("df12")
data13= pd.read_csv("df13")
data14= pd.read_csv("df14")
data15= pd.read_csv("df15")
data16= pd.read_csv("df16")
data17= pd.read_csv("df17")
data18= pd.read_csv("df18")
data19= pd.read_csv("df19")
data20= pd.read_csv("df20")
data21= pd.read_csv("df21")
data22= pd.read_csv("df22")

# %%
df = pd.concat([data1,data2,data3,data4,data5,data6,data7,data8,data9,data10,data11,data12,data13,data14,data15,data16,data17,data18,data19,data20,data21,data22])

# %%
df
# Out:
#      Unnamed: 0 Airline name       From       To     Arival time Depart time  \
# 0             0    Air India  New Delhi   Mumbai           23:35       21:20
# 1             1    Air India  New Delhi   Mumbai  00:45\n+ 1 day       22:30
# 2             2     Go First  New Delhi   Mumbai           22:05       20:00
# 3             3     Go First  New Delhi   Mumbai           23:15       21:00
# 4             4       IndiGo  New Delhi   Mumbai  01:20\n+ 1 day       23:00
# ..          ...          ...        ...      ...             ...         ...
# 98           98      Vistara  New Delhi  Kolkata  09:40\n+ 1 day       17:35
# 99           99      Vistara  New Delhi  Kolkata           16:50       09:30
# 100         100      Vistara  New Delhi  Kolkata           19:50       09:30
# 101         101    Air India  New Delhi  Kolkata           23:00       14:00
# 102         102      Vistara  New Delhi  Kolkata  09:40\n+ 1 day       18:40
#
#       Stoppage Duration   Price
# ...

# %%
#to save the dataframe 
df.to_csv('flightdata.csv', index=True)
